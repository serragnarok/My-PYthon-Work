# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_html('https://tw.stock.yahoo.com/d/i/rank.php?t=up&e=tse',encoding='big5')

# %%
df = df[3]
df.head()
column_name = df.loc[0, :]
df.columns = column_name

# %%
df = df.drop(0)

# %%
df.sort_values("成交值(億)",ascending=True)
# Out:
# 0   名次     股票代號/名稱     成交價      漲跌     漲跌幅      最高      最低     價差   成交張數  \
# 10  10     1475 本盟    4.75   △0.29  +6.50%    4.75    4.75   0.00      3
# 3    3     9928 中視    5.19   △0.37  +7.68%    5.19    4.99   0.20     11
# 1    1    3383 新世紀    4.12   △0.35  +9.28%    4.14    4.12   0.02     60
# 12  12    2712 遠雄來   56.60   △3.40  +6.39%   56.60   51.00   5.60     20
# 29  29     2496 卓越   67.50   △2.90  +4.49%   67.50   65.80   1.70     36
# 16  16     2457 飛宏    8.97   △0.50  +5.90%    9.01    8.62   0.39   1290
# 7    7     1456 怡華   11.20   △0.75  +7.18%   11.40   10.40   1.00   1129
# 5    5    9906 欣巴巴   16.85   △1.15  +7.32%   17.25   15.90   1.35    911
# 27  27  2939 凱羿-KY  114.00   △5.00  +4.59%  116.00  108.00   8.00    170
# 4    4    2816 旺旺保   21.30   △1.50  +7.58%   21.50   19.90   1.60   1821
# 28  28     2478 大毅   39.50   △1.70  +4.50%   39.50   37.90   1.60   1334
# 9    9     4536 拓凱  130.00   △8.00  +6.56%  132.00  124.00   8.00    547
# ...
