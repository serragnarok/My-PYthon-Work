# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.ptt.cc/bbs/NBA/index.html"

def get_all_href(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    results = soup.select("div.title")
    for item in results:
        a_item = item.select_one("a")
        title = item.text
        if a_item:
            if (title.find('Live') == -1 & title.find('BOX')):
                print(title, 'https://www.ptt.cc'+ a_item.get('href'))
        
for page in range(1,4):
    r = requests.get(url)
    soup = BeautifulSoup(r.text,"html.parser")
    btn = soup.select('div.btn-group > a')
    up_page_href = btn[3]['href']
    next_page_url = 'https://www.ptt.cc' + up_page_href
    url = next_page_url
    get_all_href(url = url)
# Out:
# Re: [情報] Carmelo Anthony western player of the
#  https://www.ptt.cc/bbs/NBA/M.1575326811.A.363.html
#
# [討論] Kobe的三節62 vs Harden的三節60
#  https://www.ptt.cc/bbs/NBA/M.1575327435.A.37D.html
#
# [情報] D.Green:LBJ會主動承認自己場上犯的錯誤
#  https://www.ptt.cc/bbs/NBA/M.1575332151.A.E4D.html
#
# [情報] 上週東西區最佳球員：字母哥，Anthony
#  https://www.ptt.cc/bbs/NBA/M.1575333238.A.F1B.html
#
# [花邊] 林書豪回NBA？美媒建議這五隊應該簽下他
#  https://www.ptt.cc/bbs/NBA/M.1575337844.A.371.html
#
# [情報] Doc Rivers: KL和PG還沒一起練過一場球
#  https://www.ptt.cc/bbs/NBA/M.1575337865.A.C87.html
#
# Re: [討論] Kobe的三節62 vs Harden的三節60
#  https://www.ptt.cc/bbs/NBA/M.1575338794.A.0DA.html
#
# [情報] 瓜瓜ig：動力、努力、耐心與家庭
#  https://www.ptt.cc/bbs/NBA/M.1575339400.A.F3B.html
#
# [討論] 今年明星賽還會有特別增額嗎?
#  https://www.ptt.cc/bbs/NBA/M.1575339656.A.34F.html
#
# [情報] 單月最佳教練: 暴龍Nurse / 湖人Vogel
#  https://www.ptt.cc/bbs/NBA/M.1575341558.A.0B7.html
#
# [討論] NBA League Pass畫質問題
#  https://www.ptt.cc/bbs/NBA/M.1575342969.A.B66.html
#
# [討論] 明年奧運3x3應該是看不到現役NBA球員了
#  https://www.ptt.cc/bbs/NBA/M.1575280300.A.724.html
#
# [討論] 吹羊的模板
#  https://www.ptt.cc/bbs/NBA/M.1575284727.A.D28.html
#
# [情報] 格林：年輕球員提升關鍵球表現需要時間
#  https://www.ptt.cc/bbs/NBA/M.1575285596.A.9B6.html
#
# [情報] ★今日排名(2019.12.02)★
#  https://www.ptt.cc/bbs/NBA/M.1575292857.A.9D8.html
#
# [討論] DH傳統中鋒的打法要怎麼改才不容易被吹犯規?
#  https://www.ptt.cc/bbs/NBA/M.1575294016.A.94C.html
#
# [討論] 明星賽先發會是哪些球員
#  https://www.ptt.cc/bbs/NBA/M.1575294992.A.CEC.html
#
# [新聞] 快艇再爆150分 巫師教頭：攻守兼備
#  https://www.ptt.cc/bbs/NBA/M.1575298184.A.46A.html
#
# [外絮] 12月NBA需要關注的6件事
#  https://www.ptt.cc/bbs/NBA/M.1575299982.A.543.html
#
# [情報] NBA 考慮為季中錦標賽贏家額外提供選秀權
#  https://www.ptt.cc/bbs/NBA/M.1575301104.A.A8A.html
#
